# %%
# Load data from text file
with open('../corpora/snaps_corpa_train.txt', 'r') as file:
    sentences_train = file.read().splitlines()

# %%
# Load data from text file
with open('../corpora/snaps_corpa_test.txt', 'r') as file:
    sentences_test = file.read().splitlines()

# %%
def get_word_set(file):
    
    for line in file:
        for word in line:
# Out:
# ['servicenow-servicenowquery flow-router transform-datatransform transform-sort flow-head transform-groupbyn transform-datatransform rest-post',
#  'rest-get transform-datatransform google-spreadsheet-worksheetwriter',
#  'snowflake-execute transform-multijoin transform-datatransform flow-router transform-sort transform-multijoin transform-conditional transform-datatransform flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'snowflake-execute transform-multijoin transform-datatransform flow-router flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-datatransform transform-groupbyn transform-datatransform transform-jsonsplitter transform-datatransform transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy snowflake-scd2 transform-datatransform flow-router transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-datatransform transform-groupbyn transform-datatransform transform-jsonsplitter transform-datatransform transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy snowflake-scd2 transform-datatransform flow-router transform-multijoin transform-datatransform flow-router transform-sort transform-multijoin transform-conditional transform-datatransform flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-datatransform transform-groupbyn transform-datatransform transform-jsonsplitter transform-datatransform transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy snowflake-scd2 transform-datatransform flow-router transform-multijoin transform-datatransform flow-router flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-datatransform transform-groupbyn transform-datatransform transform-jsonsplitter transform-datatransform transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy transform-sort transform-multijoin transform-conditional transform-datatransform flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy snowflake-scd2 transform-datatransform flow-router transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy snowflake-scd2 transform-datatransform flow-router transform-multijoin transform-datatransform flow-router transform-sort transform-multijoin transform-conditional transform-datatransform flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy snowflake-scd2 transform-datatransform flow-router transform-multijoin transform-datatransform flow-router flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'workday-workdayread transform-datatransform transform-sort transform-groupbyfields transform-datatransform transform-datatransform flow-copy transform-sort transform-multijoin transform-datatransform transform-datatransform transform-datatransform flow-filter flow-copy transform-sort transform-multijoin transform-conditional transform-datatransform flow-union transform-datatransform transform-datatransform flow-union snowflake-bulkupsert',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'transform-jsongenerator flow-copy transform-datatransform',
#  'rest-get transform-jsonsplitter transform-datatransform snowflake-insert',
#  'rest-get transform-datatransform rest-get transform-jsonsplitter transform-datatransform flow-copy sqlserver-insert',
#  'rest-get transform-datatransform rest-get transform-jsonsplitter transform-datatransform flow-copy flow-filter transform-datatransform rest-get transform-datatransform transform-datatransform flow-copy transform-jsonsplitter flow-union flow-filter transform-datatransform sqlserver-insert',
#  'rest-get transform-datatransform rest-get transform-jsonsplitter transform-datatransform flow-copy flow-filter transform-datatransform rest-get transform-datatransform transform-datatransform flow-copy transform-jsonsplitter flow-union flow-filter transform-datatransform sqlserver-insert',
#  'rest-get transform-datatransform rest-get transform-jsonsplitter transform-datatransform flow-copy flow-filter transform-datatransform rest-get transform-datatransform transform-datatransform flow-copy transform-jsonsplitter flow-union flow-filter transform-datatransform sqlserver-insert',
#  'salesforce-subscriber transform-jsonsplitter salesforce-read transform-jsonformatter jms-jmsproducer',
#  'transform-datatransform flow-router transform-jsonsplitter flow-union snaplogic-read flow-filter transform-datatransform transform-groupbyn transform-jsonformatter binary-zip',
#  'transform-datatransform flow-router transform-jsonsplitter flow-union snaplogic-read transform-datatransform transform-jsonformatter binary-zip',
#  'transform-datatransform flow-router snaplogic-list flow-union snaplogic-read flow-filter transform-datatransform transform-groupbyn transform-jsonformatter binary-zip',
#  'transform-datatransform flow-router snaplogic-list flow-union snaplogic-read transform-datatransform transform-jsonformatter binary-zip',
#  'binary-simpleread transform-binarytodocument transform-multijoin transform-datatransform salesforce-create',
#  'salesforce-read transform-datatransform transform-multijoin transform-datatransform salesforce-create',
#  'azuresql-execute transform-datatransform salesforce-upsert transform-datatransform transform-jsonformatter binary-write',
#  'azuresql-execute transform-datatransform salesforce-upsert transform-jsonformatter binary-write',
#  'transform-datatransform flow-router rest-post flow-union',
#  'transform-datatransform flow-router rest-patch flow-union',
#  'oracle-select transform-groupbyn transform-xmlgenerator transform-datatransform transform-documenttobinary binary-write',
#  'rest-get transform-datatransform flow-copy rest-get rest-get transform-jsonsplitter',
#  'rest-get transform-datatransform flow-copy rest-get transform-jsonsplitter transform-datatransform',
#  'binary-simpleread transform-jsonparser transform-csvformatter binary-write',
#  'servicenow-servicenowquery transform-datatransform transform-groupbyn transform-datatransform rest-post',
#  'transform-datatransform oracle-lookup flow-filter transform-datatransform sap-execute rest-get',
#  'transform-jsongenerator transform-groupbyfields transform-datatransform transform-datatransform',
#  'binary-simpleread transform-excelparser transform-aggregate transform-datatransform',
#  'mqtt-mqttreader transform-jsonparser transform-jsonformatter binary-write',
#  'rabbitmq-messageconsumer transform-binarytodocument mysql-insert flow-router rabbitmq-messageacknowledge',
#  'rabbitmq-messageconsumer transform-binarytodocument mysql-insert flow-router transform-datatransform rabbitmq-messageacknowledge transform-jsonformatter binary-write',
#  'rabbitmq-messageconsumer transform-binarytodocument mysql-insert transform-datatransform rabbitmq-messageacknowledge transform-jsonformatter binary-write',
#  'transform-datatransform transform-conditional transform-datatransform flow-copy transform-datatransform script-script transform-datatransform transform-multijoin',
#  'transform-datatransform transform-conditional transform-datatransform flow-copy transform-multijoin',
#  'salesforce-read transform-datatransform flow-filter flow-head transform-datatransform workday-workdaywrite',
#  'binary-simpleread transform-jsonparser transform-datatransform netsuite-create',
#  'transform-jsongenerator transform-datatransform',
#  'transform-jsongenerator transform-datatransform',
#  'binary-read transform-csvparser transform-datatransform flow-router oracle-insert',
#  'binary-read transform-csvparser transform-datatransform flow-router oracle-insert',
#  'rest-get flow-union',
#  'rest-get transform-datatransform flow-union',
#  'snaplogic-read transform-datatransform snaplogic-update',
#  'transform-datatransform transform-groupbyfields mysql-lookup flow-filter transform-datatransform transform-datatransform transform-jsonsplitter transform-datatransform flow-copy flow-tail transform-datatransform mysql-update',
#  'transform-datatransform transform-groupbyfields mysql-lookup flow-filter transform-datatransform transform-datatransform transform-jsonsplitter transform-datatransform flow-copy transform-datatransform mysql-insert',
#  'binary-directorybrowser binary-simpleread binary-compress transform-binarytodocument transform-datatransform hadoop-sequenceformatter hadoop-hdfswrite',
#  'transform-datatransform workday-workdayread transform-datatransform rest-get flow-router transform-datatransform rest-put transform-datatransform flow-union transform-datatransform snowflake-insert',
#  'transform-datatransform workday-workdayread transform-datatransform rest-get flow-router transform-datatransform rest-post transform-datatransform flow-union transform-datatransform snowflake-insert',
#  'flow-router transform-datatransform sqlserver-insert flow-union',
#  'flow-router transform-datatransform azuresql-update flow-union',
#  'flow-router transform-jsonformatter binary-write',
#  'flow-router transform-datatransform transform-datatransform azuresql-update flow-union',
#  'salesforce-subscriber salesforce-read flow-router transform-datatransform flow-union transform-datatransform dynamicsfo-create transform-datatransform salesforce-update',
#  'salesforce-subscriber salesforce-read flow-router salesforce-read transform-datatransform flow-union transform-datatransform dynamicsfo-create transform-datatransform salesforce-update',
#  'binary-simpleread transform-xmlparser transform-jsonsplitter transform-datatransform flow-filter transform-datatransform workday-workdayread transform-datatransform workday-workdayread transform-datatransform servicenow-servicenowinsert',
#  'salesforce-read transform-datatransform transform-csvformatter hadoop-hdfswrite',
#  'rest-get flow-union transform-datatransform salesforce-create transform-datatransform',
#  'rest-get flow-union transform-datatransform salesforce-create transform-datatransform',
#  'workday-workdayread transform-jsonsplitter transform-datatransform transform-datatransform transform-csvformatter binary-write',
#  'transform-datatransform salesforce-read transform-sort transform-unique box-addfolder transform-datatransform rest-put',
#  'salesforce-query flow-router transform-multijoin transform-datatransform transform-multijoin flow-router transform-datatransform transform-multijoin transform-datatransform netsuite-create transform-datatransform salesforce-update',
#  'salesforce-query flow-router transform-multijoin transform-datatransform transform-multijoin flow-router transform-jsonsplitter transform-datatransform transform-groupbyfields transform-multijoin transform-datatransform netsuite-create transform-datatransform salesforce-update',
#  'salesforce-query flow-router transform-datatransform netsuite-create transform-datatransform salesforce-update transform-multijoin transform-datatransform transform-multijoin flow-router transform-datatransform transform-multijoin transform-datatransform netsuite-create transform-datatransform salesforce-update',
#  'salesforce-query flow-router transform-datatransform netsuite-create transform-datatransform salesforce-update transform-multijoin transform-datatransform transform-multijoin flow-router transform-jsonsplitter transform-datatransform transform-groupbyfields transform-multijoin transform-datatransform netsuite-create transform-datatransform salesforce-update',
#  'salesforce-query flow-head transform-multijoin flow-router transform-datatransform transform-multijoin transform-datatransform netsuite-create transform-datatransform salesforce-update',
#  'salesforce-query flow-head transform-multijoin flow-router transform-jsonsplitter transform-datatransform transform-groupbyfields transform-multijoin transform-datatransform netsuite-create transform-datatransform salesforce-update',
#  'salesforce-read flow-head servicenow-servicenowquery transform-datatransform servicenow-servicenowinsert',
#  'amazonsqs-amazonsqsconsumer flow-binaryrouter transform-binarytodocument transform-datatransform transform-multijoin flow-filter amazonsqs-amazonsqsacknowledge',
#  'amazonsqs-amazonsqsconsumer flow-binaryrouter transform-jsonparser transform-datatransform binary-s3filereader transform-jsonparser transform-jsonsplitter transform-datatransform redshift-bulkupdate flow-gate transform-datatransform transform-multijoin flow-filter amazonsqs-amazonsqsacknowledge',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router transform-datatransform flow-union salesforce-read transform-datatransform salesforce-read transform-datatransform salesforce-read transform-datatransform transform-datatransform flow-router salesforce-update transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router transform-datatransform flow-union salesforce-read transform-datatransform salesforce-read transform-datatransform salesforce-read transform-datatransform transform-datatransform flow-router salesforce-create transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router transform-datatransform flow-union salesforce-read transform-datatransform salesforce-read transform-datatransform salesforce-read transform-datatransform transform-datatransform flow-router salesforce-update transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router transform-datatransform flow-union salesforce-read transform-datatransform salesforce-read transform-datatransform salesforce-read transform-datatransform transform-datatransform flow-router salesforce-create transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router transform-datatransform',
#  'transform-datatransform transform-datatransform flow-router salesforce-read flow-router salesforce-delete transform-datatransform',
#  'transform-datatransform flow-copy transform-documenttobinary hadoop-hdfswrite',
#  'transform-datatransform flow-copy transform-documenttobinary binary-write',
#  'servicenow-servicenowquery flow-router transform-datatransform transform-sort flow-head transform-groupbyn transform-datatransform rest-post',
#  'transform-datatransform transform-jsongenerator rest-post flow-copy transform-jsonsplitter transform-sequence transform-multijoin transform-datatransform google-spreadsheet-worksheetwriter',
#  'transform-datatransform transform-jsongenerator rest-post flow-copy transform-jsonsplitter transform-sequence transform-multijoin transform-datatransform google-spreadsheet-worksheetwriter',
#  'rest-get transform-jsonsplitter flow-copy transform-datatransform dynamics365forsales-create flow-union transform-multijoin transform-datatransform transform-jsonformatter transform-binarytodocument transform-datatransform transform-datatransform rest-post',
#  'rest-get transform-jsonsplitter flow-copy transform-datatransform dynamics365forsales-create flow-union transform-multijoin transform-datatransform transform-jsonformatter transform-binarytodocument transform-datatransform transform-datatransform rest-post',
#  'rest-get transform-jsonsplitter flow-copy transform-multijoin transform-datatransform transform-jsonformatter transform-binarytodocument transform-datatransform transform-datatransform rest-post',
#  'binary-simpleread transform-csvparser sqlserver-lookup transform-datatransform flow-union transform-datatransform workday-workdaywrite',
#  'binary-simpleread transform-csvparser sqlserver-lookup transform-datatransform flow-union transform-datatransform workday-workdaywrite',
#  'azuresql-execute transform-datatransform salesforce-subscriber flow-pipeexec',
#  'binary-simpleread transform-csvparser flow-copy transform-inmemorylookup flow-router transform-datatransform salesforce-update',
#  'binary-simpleread transform-csvparser flow-copy transform-inmemorylookup flow-router transform-datatransform salesforce-create',
#  'binary-simpleread transform-csvparser flow-copy salesforce-lookup transform-inmemorylookup flow-router transform-datatransform salesforce-update',
#  'binary-simpleread transform-csvparser flow-copy salesforce-lookup transform-inmemorylookup flow-router transform-datatransform salesforce-create',
#  'transform-datatransform flow-copy transform-xmlformatter transform-binarytodocument rest-post',
#  'transform-datatransform flow-copy transform-xmlformatter binary-write',
#  'binary-simpleread transform-csvparser salesforce-lookup salesforce-delete',
#  'transform-datatransform sap-execute transform-jsonsplitter flow-filter flow-head transform-datatransform dynamicscrm-create',
#  'transform-datatransform sap-execute flow-pipeexec',
#  'salesforce-read transform-datatransform salesforce-attachmentdownload transform-documenttobinary box-boxwrite',
#  'salesforce-query flow-tail salesforce-lookup transform-structuraltransform transform-conditional transform-sequence transform-datatransform tableau9-rest-tableaurest',
#  'binary-simpleread transform-jsonparser flow-filter transform-datatransform workday-workdayread transform-datatransform sqlserver-bulkload',
#  'binary-simpleread binary-write binary-delete',
#  'binary-simpleread transform-excelparser transform-datatransform rest-post transform-jsonformatter binary-write',
#  'binary-simpleread transform-excelparser transform-datatransform rest-post transform-jsonformatter binary-write',
#  'flow-pipeexec rest-get transform-jsonsplitter transform-datatransform redshift-insert',
#  'transform-datatransform workday-workdayread flow-head transform-datatransform transform-conditional transform-datatransform tableau9-rest-tableaurest',
#  'transform-csvgenerator flow-router sqlserver-lookup transform-datatransform flow-union flow-copy transform-datatransform oracle-merge',
#  'transform-csvgenerator flow-router sqlserver-lookup transform-datatransform flow-union flow-copy transform-datatransform redshift-insert',
#  'transform-csvgenerator flow-router oracle-lookup transform-datatransform flow-union flow-copy transform-datatransform oracle-merge',
#  'transform-csvgenerator flow-router oracle-lookup transform-datatransform flow-union flow-copy transform-datatransform redshift-insert',
#  'transform-datatransform sap-execute transform-jsonsplitter transform-multijoin transform-datatransform servicenow-servicenowinsert',
#  'rest-get transform-jsonsplitter transform-datatransform transform-multijoin transform-datatransform servicenow-servicenowinsert',
#  'salesforce-read transform-datatransform flow-copy transform-jsonformatter hadoop-hdfswrite',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform oracle-insert',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform snowflake-bulkload',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform redshift-bulkload',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform google-bigquery-write',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform transform-csvformatter binary-s3filewriter',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform hadoop-parquetwritingformatter',
#  'transform-csvgenerator transform-datatransform',
#  'snowflake-execute binary-directorybrowser flow-filter binary-simpleread transform-binarytodocument snowflake-bulkload snowflake-select',
#  'transform-datatransform transform-jsongenerator rest-post flow-copy transform-jsonsplitter transform-sequence transform-multijoin transform-datatransform rest-post',
#  'transform-datatransform transform-jsongenerator rest-post flow-copy transform-jsonsplitter transform-sequence transform-multijoin transform-datatransform rest-post',
#  'binary-directorybrowser flow-filter flow-filter binary-delete',
#  'sqlserver-select snowflake-bulkload',
#  'sqlserver-select snowflake-bulkload',
#  'salesforce-read transform-jsonformatter jms-jmsproducer',
#  'rest-post transform-datatransform transform-multijoin flow-pipeexec',
#  'salesforce-subscriber salesforce-read flow-copy transform-datatransform transform-multijoin flow-filter sqlserver-select transform-datatransform transform-multijoin flow-pipeexec',
#  'salesforce-subscriber salesforce-read flow-copy salesforce-read flow-copy salesforce-read transform-datatransform transform-multijoin flow-filter sqlserver-select transform-datatransform transform-multijoin flow-pipeexec',
#  'salesforce-subscriber salesforce-read flow-copy salesforce-read flow-copy transform-datatransform transform-multijoin flow-filter sqlserver-select transform-datatransform transform-multijoin flow-pipeexec',
#  'salesforce-subscriber salesforce-read flow-copy salesforce-read transform-datatransform transform-multijoin flow-filter sqlserver-select transform-datatransform transform-multijoin flow-pipeexec',
#  'transform-datatransform netsuite-search transform-jsonsplitter flow-head transform-datatransform flow-copy transform-multijoin transform-datatransform servicenow-servicenowinsert',
#  'transform-datatransform netsuite-search transform-jsonsplitter flow-head transform-datatransform flow-copy transform-datatransform netsuite-lookup transform-datatransform transform-multijoin transform-datatransform servicenow-servicenowinsert',
#  'salesforce-read flow-filter transform-datatransform netsuite-search flow-router transform-datatransform netsuite-create transform-datatransform email-emailsender',
#  'salesforce-read flow-filter transform-datatransform netsuite-search flow-router transform-datatransform netsuite-create transform-datatransform flow-union email-emailsender',
#  'salesforce-read flow-filter transform-datatransform netsuite-search flow-router transform-datatransform netsuite-update transform-datatransform email-emailsender',
#  'salesforce-read flow-filter transform-datatransform netsuite-search flow-router transform-datatransform netsuite-update flow-union email-emailsender',
#  'salesforce-read flow-filter transform-datatransform netsuite-search flow-union email-emailsender',
#  'salesforce-read flow-union email-emailsender',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy flow-pipeexec',
#  'binary-simpleread binary-pgpdecrypt transform-binarytodocument transform-jsonsplitter flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-router flow-union flow-router transform-datatransform workday-workdaywrite transform-datatransform transform-datatransform flow-union flow-copy transform-datatransform transform-csvformatter binary-write',
# ...
#  'redshift-select flow-router transform-datatransform redshift-multiexecute salesforce-read transform-datatransform flow-copy transform-aggregate transform-datatransform redshift-multiexecute',
#  'transform-xmlparser transform-jsonformatter transform-jsonparser transform-jsonsplitter transform-datatransform transform-groupbyn transform-datatransform transform-datatransform workday-workdayread transform-jsonsplitter transform-datatransform servicenow-servicenowinsert transform-datatransform email-emailsender',
#  'salesforce-read transform-jsonformatter amazonsqs-amazonsqsproducer',
#  'salesforce-query transform-conditional flow-router flow-exit',
#  'salesforce-query transform-conditional flow-router transform-datatransform workday-workdaywrite transform-datatransform salesforce-update',
#  'binary-simpleread binary-write google-bigquery-bulkloadfromcloudstorage',
#  'box-browser box-boxread transform-csvparser transform-datatransform redshift-update',
#  'transform-datatransform transform-datatransform flow-copy email-emailsender',
#  'transform-datatransform transform-datatransform flow-copy transform-datatransform rest-post',
#  'transform-datatransform soap-soapexecute transform-datatransform soap-soapexecute',
#  'snaplogic-list snaplogic-read flow-router transform-datatransform snaplogic-update',
#  'snaplogic-list snaplogic-read flow-router transform-datatransform snaplogic-update',
#  'binary-simpleread transform-excelparser transform-jsongenerator rest-post',
#  'binary-directorybrowser flow-pipeexec flow-pipeexec flow-router transform-jsonsplitter flow-filter flow-router flow-pipeexec flow-filter binary-simpleread binary-write binary-fileoperation',
#  'transform-sequence transform-multijoin flow-router transform-datatransform email-emailsender',
#  'transform-sequence transform-multijoin flow-router email-emailsender',
#  'jira-search transform-datatransform transform-sort transform-datatransform transform-multijoin flow-router transform-datatransform email-emailsender',
#  'jira-search transform-datatransform transform-sort transform-datatransform transform-multijoin flow-router email-emailsender',
#  'transform-datatransform servicenow-servicenowinsert transform-datatransform email-emailsender',
#  'salesforce-query salesforce-query salesforce-query salesforce-query salesforce-query transform-datatransform transform-structuraltransform sap-execute transform-aggregate transform-structuraltransform salesforce-update transform-jsonformatter binary-write',
#  'redshift-select flow-router transform-datatransform redshift-multiexecute binary-simpleread binary-s3filewriter transform-datatransform redshift-multiexecute',
#  'redshift-select flow-router transform-jsonformatter binary-write',
#  'rest-get transform-datatransform flow-filter',
#  'salesforce-read transform-sort transform-multijoin transform-datatransform salesforce-create',
#  'oracle-select transform-sort transform-multijoin transform-datatransform salesforce-create',
#  'transform-datatransform netsuite-search transform-jsonsplitter flow-head transform-datatransform servicenow-servicenowquery transform-datatransform servicenow-servicenowinsert',
#  'email-emailreader transform-datatransform binary-simpleread box-boxwrite',
#  'salesforce-read flow-head transform-datatransform flow-copy transform-multijoin transform-datatransform servicenow-servicenowinsert',
#  'salesforce-read flow-head transform-datatransform flow-copy salesforce-read transform-multijoin transform-datatransform servicenow-servicenowinsert',
#  'rest-get transform-jsonsplitter',
#  'oracle-execute transform-datatransform transform-groupbyfields transform-jsongenerator transform-datatransform flow-copy flow-pipeexec transform-multijoin hive-execute transform-jsonformatter binary-write',
#  'oracle-execute transform-datatransform transform-groupbyfields transform-jsongenerator transform-datatransform flow-copy flow-pipeexec transform-multijoin hive-execute transform-jsonformatter binary-write',
#  'transform-datatransform netsuite-search transform-jsonsplitter transform-datatransform redshift-bulkload',
#  'workday-workdayread transform-jsonsplitter transform-datatransform flow-copy oracle-insert',
#  'workday-workdayread transform-jsonsplitter transform-datatransform flow-copy transform-datatransform rest-post',
#  'transform-csvgenerator flow-head transform-csvformatter transform-csvparser flow-head transform-datatransform flow-copy transform-csvformatter binary-write',
#  'transform-csvgenerator flow-head transform-csvformatter transform-csvparser flow-head transform-datatransform flow-copy script-script transform-datatransform transform-jsonformatter binary-write',
#  'flow-pipeexec transform-multijoin rest-post',
#  'transform-datatransform salesforce-read transform-jsongenerator transform-multijoin rest-post',
#  'transform-datatransform dynamicscrm-create dynamicscrm-read transform-datatransform workday-workdaywrite',
#  'confluentkafka-confluentkafkaconsumer transform-datatransform snowflake-bulkload',
#  'dynamicscrm-read flow-filter transform-datatransform transform-jsongenerator rest-post',
#  'rest-get flow-union transform-datatransform flow-union email-emailsender',
#  'rest-get transform-datatransform transform-jsonsplitter rest-get transform-datatransform flow-union email-emailsender',
#  'rest-get transform-datatransform transform-jsonsplitter rest-get flow-union transform-datatransform flow-union email-emailsender',
#  'transform-datatransform transform-sort transform-groupbyfields',
#  'transform-datatransform rest-get flow-router flow-union transform-jsonformatter binary-write',
#  'transform-datatransform rest-get flow-router transform-datatransform flow-filter transform-jsonsplitter transform-datatransform transform-csvformatter binary-write',
#  'transform-datatransform rest-get flow-union transform-jsonformatter binary-write',
#  'transform-datatransform workday-workdayread transform-datatransform transform-diff transform-datatransform workday-workdaywrite',
#  'oracle-execute transform-diff transform-datatransform workday-workdaywrite',
#  'transform-jsongenerator rest-post transform-jsonsplitter',
#  'rest-post transform-datatransform transform-documenttobinary transform-csvparser',
#  'transform-datatransform rest-post rest-get transform-jsonsplitter transform-datatransform rest-post slack-sendmessage',
#  'transform-jsongenerator transform-encryptfield transform-datatransform transform-decryptfield',
#  'transform-datatransform transform-multijoin transform-datatransform',
#  'binary-simpleread transform-csvparser transform-datatransform transform-sort transform-groupbyn transform-multijoin transform-datatransform',
#  'transform-datatransform transform-datatransform workday-workdayread transform-jsonsplitter transform-datatransform transform-datatransform transform-csvformatter binary-write',
#  'rest-get transform-jsonsplitter flow-copy transform-aggregate flow-union transform-csvformatter binary-write',
#  'rest-get transform-jsonsplitter flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform flow-union transform-csvformatter binary-write',
#  'transform-datatransform transform-jsongenerator transform-datatransform rest-post',
#  'jms-jmsconsumer transform-binarytodocument transform-datatransform transform-datatransform oracle-execute transform-datatransform jms-jmsacknowledge',
#  'salesforce-read transform-datatransform netsuite-create flow-copy transform-datatransform reltiosnapconnector-reltiowrite',
#  'salesforce-read transform-datatransform netsuite-create flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform servicenow-servicenowquery flow-router transform-datatransform flow-router transform-sort flow-head transform-groupbyn transform-datatransform rest-post',
#  'mysql-select teradata-tptload teradata-execute',
#  'transform-datatransform transform-multijoin transform-datatransform',
#  'ldap-ldapsearch flow-filter transform-datatransform transform-groupbyn flow-union transform-multijoin transform-datatransform',
#  'ldap-ldapsearch transform-datatransform flow-union transform-multijoin transform-datatransform',
#  'binary-simpleread transform-excelparser flow-copy transform-multijoin sqlserver-execute',
#  'binary-simpleread transform-excelparser flow-copy flow-filter sqlserver-delete transform-datatransform transform-multijoin sqlserver-execute',
#  'hadoop-hdfsread transform-csvparser flow-filter transform-jsonformatter hadoop-hdfswrite',
#  'workday-workdayread flow-filter transform-datatransform jira-create jira-get',
#  'oracle-execute transform-datatransform transform-sort transform-groupbyfields transform-jsongenerator confluentkafka-confluentkafkaproducer',
#  'transform-jsongenerator transform-datatransform flow-copy transform-datatransform sqlserver-insert',
#  'transform-jsongenerator transform-datatransform flow-copy transform-jsonsplitter flow-router transform-datatransform sqlserver-insert',
#  'transform-jsongenerator transform-datatransform flow-copy transform-jsonsplitter flow-router transform-datatransform sqlserver-insert',
#  'transform-jsongenerator transform-datatransform flow-copy transform-jsonsplitter flow-router transform-datatransform sqlserver-insert',
#  'transform-jsongenerator transform-datatransform flow-copy transform-jsonsplitter flow-router transform-datatransform sqlserver-insert',
#  'transform-jsongenerator flow-datavalidator transform-unique',
#  'transform-jsongenerator flow-datavalidator email-emailsender',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get flow-router flow-union transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get flow-router transform-datatransform rest-post flow-router transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get flow-router transform-datatransform rest-post flow-router transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get flow-router transform-datatransform rest-post flow-union transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get transform-datatransform flow-router transform-datatransform rest-patch flow-union transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get transform-datatransform flow-router transform-datatransform rest-patch transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'transform-datatransform transform-jsonsplitter transform-datatransform rest-get transform-datatransform flow-router transform-datatransform flow-union transform-unique flow-copy transform-jsonformatter binary-write',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform sqlserver-insert',
#  'salesforce-read transform-datatransform flow-copy transform-datatransform mongo-insert transform-datatransform oracle-insert',
#  'transform-jsongenerator transform-datatransform flow-copy transform-multijoin transform-datatransform',
#  'transform-jsongenerator transform-datatransform flow-copy transform-multijoin transform-datatransform',
#  'transform-jsongenerator transform-datatransform flow-copy transform-multijoin transform-datatransform',
#  'transform-jsongenerator transform-datatransform flow-copy transform-multijoin transform-datatransform',
#  'binary-simpleread transform-csvparser transform-jsonformatter binary-write',
#  'servicenow-servicenowquery transform-datatransform box-browser flow-router box-addfolder transform-datatransform rest-put',
#  'transform-datatransform script-script transform-jsonformatter binary-write',
#  'transform-datatransform rest-post rest-get transform-jsonsplitter transform-datatransform transform-multijoin transform-datatransform rest-post',
#  'rest-get transform-jsonsplitter transform-multijoin transform-datatransform rest-post',
#  'box-boxread transform-csvparser google-spreadsheet-worksheetwriter',
#  'snaplogic-list snaplogic-list snaplogic-list transform-datatransform transform-multijoin transform-datatransform transform-sort google-spreadsheet-worksheetwriter',
#  'rest-get transform-jsonsplitter transform-groupbyfields transform-datatransform transform-multijoin transform-datatransform transform-sort google-spreadsheet-worksheetwriter',
#  'salesforce-read transform-multijoin flow-filter transform-csvformatter binary-write',
#  'salesforce-read transform-multijoin flow-filter transform-csvformatter binary-write',
#  'transform-sequence transform-groupbyn transform-multijoin transform-datatransform transform-jsonsplitter transform-datatransform',
#  'transform-csvgenerator flow-copy transform-datatransform transform-multijoin transform-datatransform transform-jsonsplitter transform-datatransform',
#  'transform-csvgenerator flow-copy transform-pivot',
#  'transform-datatransform netsuite-lookup transform-datatransform transform-datatransform transform-jsongenerator rest-post',
#  'binary-simpleread transform-jsonparser transform-datatransform transform-sort transform-diff transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser transform-datatransform transform-sort transform-diff flow-union transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser transform-datatransform transform-sort transform-diff flow-union transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser transform-datatransform transform-sort transform-diff flow-union transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser flow-pipeexec transform-datatransform transform-sort transform-diff transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser flow-pipeexec transform-datatransform transform-sort transform-diff flow-union transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser flow-pipeexec transform-datatransform transform-sort transform-diff flow-union transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser flow-pipeexec transform-datatransform transform-sort transform-diff flow-union transform-aggregate transform-multijoin transform-datatransform flow-filter flow-exit',
#  'binary-simpleread transform-jsonparser transform-datatransform workday-workdaywrite',
#  'transform-datatransform flow-pipeexec rest-get transform-jsonsplitter flow-copy transform-datatransform flow-pipeexec rest-get transform-datatransform redshift-bulkupdate',
#  'transform-datatransform flow-pipeexec rest-get transform-jsonsplitter flow-copy transform-datatransform redshift-bulkupdate',
#  'rest-get transform-jsonsplitter transform-datatransform flow-pipeexec transform-jsonformatter binary-write',
#  'rest-get transform-jsonsplitter transform-datatransform flow-pipeexec transform-datatransform transform-jsonformatter binary-write',
#  'rest-post rest-get transform-jsonsplitter',
#  'transform-datatransform workday-workdayread flow-head transform-datatransform transform-conditional transform-datatransform transform-csvformatter anaplan-upload anaplan-actionjob',
#  'transform-datatransform script-script']
